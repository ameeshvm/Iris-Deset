# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
irisdata = pd.read_csv('../input/irisdata1/iris_data.csv', index_col=None)
irisdata.head(n=10)
# Out:
#    PetalLengthCm  PetalWidthCm      Species
# 0            1.4           0.2  Iris-setosa
# 1            1.4           0.2  Iris-setosa
# 2            1.3           0.2  Iris-setosa
# 3            1.5           0.2  Iris-setosa
# 4            1.4           0.2  Iris-setosa
# 5            1.7           0.4  Iris-setosa
# 6            1.4           0.3  Iris-setosa
# 7            1.5           0.2  Iris-setosa
# 8            1.4           0.2  Iris-setosa
# 9            1.5           0.1  Iris-setosa

# %%
sns.scatterplot(x=irisdata['PetalLengthCm'], y=irisdata['PetalWidthCm'], hue=irisdata['PetalWidthCm'])
# Out:
# <Axes: xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
from sklearn.model_selection import train_test_split

irisdatafile = '../input/irisdata1/iris_data.csv'
names=['PetalWidthCm','PetalLengthCm','Species']
irisdata1=pd.read_csv(irisdatafile, names=names)
data=irisdata1.values
X=data[:,0:2]
Y=data[:,2]
X_train,X_test,Y_train, Y_test=train_test_split(X,Y,test_size=0.33,random_state=42)

# %%
sns.lmplot(x="PetalLengthCm", y="PetalWidthCm", hue="PetalLengthCm", data=irisdata)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
